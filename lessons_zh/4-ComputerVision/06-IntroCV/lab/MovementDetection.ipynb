# %% [markdown]
# ## 使用光流进行手掌运动检测
#
# 本实验是 [AI for Beginners Curriculum](http://aka.ms/ai-beginners) 的一部分。
#
# 考虑[这个视频](palm-movement.mp4)，其中一个人的手掌在稳定背景上左右/上下移动。
#
# <img src="../images/palm-movement.png" width="30%" alt="手掌运动帧"/>
#
# **你的目标**是使用光流来确定视频的哪些部分包含上下/左右运动。
#
# 首先按照课程中的描述获取视频帧：

# %%
# Code here

# %% [markdown]
# 现在，按照课程中的描述计算密集光流帧，并将密集光流转换为极坐标：

# %%
# Code here

# %% [markdown]
# 为每个光流帧构建方向直方图。直方图显示有多少向量落在某个区间内，它应该分离出帧上不同的运动方向。
#
# > 你可能还想将幅度低于某个阈值的所有向量归零。这将消除视频中的小额外运动，例如眼睛和头部。
#
# 绘制一些帧的直方图。

# %%
# Code here

# %% [markdown]
# 查看直方图，确定运动方向应该相当直接。你需要选择那些对应于上下/左右方向的区间，并且高于某个阈值。

# %%
# Code here

# %% [markdown]
# 恭喜！如果你已经完成了上述所有步骤，你已经完成了实验！
